# %%
pip install -U emcee
# Out:
# ...
#   Using cached emcee-3.1.6-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached emcee-3.1.6-py2.py3-none-any.whl (47 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.4 MB 11.8 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.4 MB 11.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.4 MB 10.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.4 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.4 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 10.2 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
pip install astroquery
# Out:
# ...
#   Using cached astroquery-0.4.11-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached keyring-25.7.0-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached jaraco_functools-4.4.0-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached astroquery-0.4.11-py3-none-any.whl (11.1 MB)
# ...
# Using cached keyring-25.7.0-py3-none-any.whl (39 kB)
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.8 MB/s  0:00:00
# Using cached pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Using cached jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# ...
# Using cached jaraco_functools-4.4.0-py3-none-any.whl (10 kB)
# ...
#
#    ----------------------------------------  0/10 [pywin32-ctypes]
#    -------- -------------------------------  2/10 [html5lib]
# ...

# %%
pip install gyrointerp
# Out:
# ...
#   Using cached gyrointerp-0.7.tar.gz (13.3 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for gyrointerp: filename=gyrointerp-0.7-py3-none-any.whl size=11639383 sha256=8e28e7ce107b25a968b11f47d18fb48631e3ec226a04701b04d50d1ddd8156b1
#   Stored in directory: c:\users\ejo08\appdata\local\pip\cache\wheels\93\e7\4a\15218ddbcfedeed84b004cf55d13b5f451f26f6af135e42f2e
# Successfully built gyrointerp
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astroquery.simbad import Simbad
import astropy.units as u
from gyrointerp import gyro_age_posterior
from astropy.io import fits

# %%
flux = fits.open('n0044_HIP55192_ts23_2020may20_spectrum.fits')

# %%
wavelength = fits.open('ts23_2020may20_thar_solution_wavearr.fits')

# %%
flux_hdul = fits.open('n0044_HIP55192_ts23_2020may20_spectrum.fits')
wave_hdul = fits.open('ts23_2020may20_thar_solution_wavearr.fits')

flux = flux_hdul[0].data
wavelength = wave_hdul[0].data

plt.figure(figsize=(10, 5))
plt.plot(wavelength, flux)

plt.xlabel(r'Wavelength ($\AA$)')
plt.ylabel(r'Flux (erg s$^{-1}$ cm$^{-2}$ $\AA^{-1}$)')
plt.title('Spectrum')
plt.grid(True)
plt.show()
